# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import gdal
gdal.SetConfigOption('SHAPE_RESTORE_SHX', 'YES')
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style('darkgrid')
plt.rcParams['figure.figsize']=(15,9)
plt.rcParams['font.size']=14

# %%
read_data=gpd.read_file("malmo.shp")
read2=gpd.read_file("malmo-pop.shp")
read3=gpd.read_file("districts.shp")
read4=gpd.read_file("countries.shp")
read5=gpd.read_file("malmo-streets.shp")
read6=gpd.read_file("preschools.shp")

# %%
read4
# Out:
#                                               geometry
# 0    MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
# ..                                                 ...
# 250  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...
# 251  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...
# 252  POLYGON ((-79.98929 15.79495, -79.98782 15.796...
# 253  POLYGON ((-78.63707 15.86209, -78.64041 15.864...
# 254  POLYGON ((117.75389 15.15437, 117.75569 15.151...
#
# [255 rows x 1 columns]

# %%
read_data.shape
# Out:
# (202, 1)

# %%
read_data.plot()
plt.show()

# %%
read_data.plot(color='grey',edgecolor='purple')
plt.show()

# %%
read_data.plot(color='grey',edgecolor='purple',alpha=0.5)
plt.show()

# %%
read_data.plot(color='grey',edgecolor='purple',alpha=0.5,linewidth=3)
plt.show()

# %%
read4.crs

# %%
read5.crs

# %%
read5.plot()
# Out:
# <AxesSubplot:>

# %%
read5.plot()
plt.show()

# %%
read6.plot(color='black',markersize=10)
# Out:
# <AxesSubplot:>
